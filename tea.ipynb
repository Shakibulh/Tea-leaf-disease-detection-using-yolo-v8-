# %%
# !pip install ultralytics

# %%
# !pip install ultralytics opencv-python-headless matplotlib

# %%
from IPython import display
display.clear_output()
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.76 🚀 Python-3.11.11 torch-2.5.1+cu124 CPU (Intel Xeon 2.20GHz)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 35.0/107.7 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pwd
# Out:
# /content

# %%
# %cd "/content/drive/MyDrive/YOLOv8"
# Out:
# /content/drive/MyDrive/YOLOv8

# %%
# !pwd
# Out:
# /content/drive/MyDrive/YOLOv8

# %%
# !ls
# Out:
# dataset1  data.yaml  runs  tea.ipynb  yolo11n.pt  yolov8s.pt

# %% [markdown]
# # **Training the Model**

# %%
# !pip install torch

# %%
import os
import torch  # Import torch for checking CUDA availability
from ultralytics import YOLO

# Ensure your working directory is set to where the data.yaml is located
os.chdir('/content/drive/MyDrive/YOLOv8')

# Load a pretrained YOLOv8 model for object detection
model = YOLO('yolov8s.pt')  # Ensure the correct weights file is used

# Check if CUDA (GPU) is available
if not torch.cuda.is_available():
    print("Warning: CUDA (GPU) is not available. Training will be slow.")
else:
    print("CUDA (GPU) is available. Training will be fast.")
# Out:
# ...
# 100%|██████████| 21.5M/21.5M [00:00<00:00, 156MB/s]
# CUDA (GPU) is available. Training will be fast.

# %%
# %pwd
# Out:
# '/content/drive/MyDrive/YOLOv8'

# %%
# Train the model
try:
    model.train(data='data.yaml', epochs=100, imgsz=640, save=True)
    print("Training complete.")
except Exception as e:
    print(f"An error occurred during training: {e}")
# Out:
# Ultralytics 8.3.75 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
from ultralytics import YOLO

# Load the model
model = YOLO('/content/drive/MyDrive/YOLOv8/runs/detect/train/weights/best.pt')

# Validate and save results
results = model.val(data='data.yaml', save=True)
# Out:
# Ultralytics 8.3.75 🚀 Python-3.11.11 torch-2.5.1+cu124 CPU (Intel Xeon 2.20GHz)
# Model summary (fused): 168 layers, 11,128,680 parameters, 0 gradients, 28.5 GFLOPs
# ...
# 100%|██████████| 755k/755k [00:00<00:00, 15.9MB/s]
# val: Scanning /content/drive/MyDrive/YOLOv8/dataset1/labels/val.cache... 252 images, 0 backgrounds, 0 corrupt: 100%|██████████| 252/252 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 16/16 [04:18<00:00, 16.17s/it]
#                    all        252        257      0.896      0.912      0.958      0.795
#        Algal Leaf Rust         30         30      0.833          1      0.988      0.848
#              Bug Eaten         26         26      0.946          1      0.989      0.888
#                Healthy         34         34          1      0.993      0.995      0.883
#            Leaf Blight         54         56      0.802       0.75      0.892       0.59
# ...

# %%
# %pwd
# Out:
# '/content/drive/MyDrive/YOLOv8'

# %% [markdown]
# # **Predict**

# %%
# Load trained YOLOv8 model
model = YOLO("/content/drive/MyDrive/YOLOv8/runs/detect/train/weights/best.pt")

# Run predictions on test images
results = model.predict(
    source="/content/drive/MyDrive/YOLOv8/dataset1/images/test",
    conf=0.25,
    save=True
)
# Out:
# image 1/253 /content/drive/MyDrive/YOLOv8/dataset1/images/test/img1008.jpg: 640x640 1 Leaf Blight, 1 Leaf Spot, 16.3ms
# image 2/253 /content/drive/MyDrive/YOLOv8/dataset1/images/test/img1011.jpg: 640x640 1 Leaf Blight, 16.3ms
# image 3/253 /content/drive/MyDrive/YOLOv8/dataset1/images/test/img1018.jpg: 640x640 1 Leaf Blight, 16.4ms
# image 4/253 /content/drive/MyDrive/YOLOv8/dataset1/images/test/img1022.jpg: 640x640 1 Leaf Spot, 16.3ms
# image 5/253 /content/drive/MyDrive/YOLOv8/dataset1/images/test/img1029.jpg: 640x640 1 Leaf Blight, 1 Leaf Spot, 16.3ms
# image 6/253 /content/drive/MyDrive/YOLOv8/dataset1/images/test/img1034.jpg: 640x640 1 Leaf Blight, 16.3ms
# image 7/253 /content/drive/MyDrive/YOLOv8/dataset1/images/test/img1039.jpg: 640x640 (no detections), 16.3ms
# image 8/253 /content/drive/MyDrive/YOLOv8/dataset1/images/test/img1042.jpg: 640x640 1 Leaf Blight, 16.3ms
# image 9/253 /content/drive/MyDrive/YOLOv8/dataset1/images/test/img1057.jpg: 640x640 1 Leaf Blight, 37.2ms
# ...

# %%
# !pip install tensorflow==2.13.1

# %% [markdown]
# # Convert To TfLite

# %%
# !pip install tensorflow==2.13.1

# %%
# !pip install --no-cache-dir sng4onnx onnx_graphsurgeon onnx onnx2tf onnxslim tflite_support onnxruntime protobuf --user

# %%
from ultralytics import YOLO

# Load a model
model = YOLO('/content/drive/MyDrive/YOLOv8/runs/detect/train/weights/best.pt')  # load a custom trained model

# Export the model
model.export(format='tflite')
# Out:
# Ultralytics 8.3.76 🚀 Python-3.11.11 torch-2.5.1+cu124 CPU (Intel Xeon 2.20GHz)
# Model summary (fused): 72 layers, 11,128,680 parameters, 0 gradients, 28.5 GFLOPs
#
# PyTorch: starting from '/content/drive/MyDrive/YOLOv8/runs/detect/train/weights/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 12, 8400) (21.5 MB)
# requirements: Ultralytics requirements ['onnx2tf>1.17.5,<=1.26.3', 'protobuf>=5'] not found, attempting AutoUpdate...
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 146.6/146.6 kB 6.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 445.6/445.6 kB 32.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 319.7/319.7 kB 194.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.3
#     Uninstalling protobuf-3.20.3:
#       Successfully uninstalled protobuf-3.20.3
#   Attempting uninstall: onnx2tf
# ...
