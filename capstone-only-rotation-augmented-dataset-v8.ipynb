# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/capstone-3-real-datasett/Capstone 3 Dataset/val/labels/img_5855.txt
# /kaggle/input/capstone-3-real-datasett/Capstone 3 Dataset/val/labels/img_5873.txt
# /kaggle/input/capstone-3-real-datasett/Capstone 3 Dataset/val/labels/img_2554.txt
# /kaggle/input/capstone-3-real-datasett/Capstone 3 Dataset/val/labels/img_9702.txt
# /kaggle/input/capstone-3-real-datasett/Capstone 3 Dataset/val/labels/img_9737.txt
# /kaggle/input/capstone-3-real-datasett/Capstone 3 Dataset/val/labels/img_3889.txt
# /kaggle/input/capstone-3-real-datasett/Capstone 3 Dataset/val/labels/img_7232.txt
# /kaggle/input/capstone-3-real-datasett/Capstone 3 Dataset/val/labels/img_4405.txt
# /kaggle/input/capstone-3-real-datasett/Capstone 3 Dataset/val/labels/img_3535.txt
# /kaggle/input/capstone-3-real-datasett/Capstone 3 Dataset/val/labels/img_1034.txt
# /kaggle/input/capstone-3-real-datasett/Capstone 3 Dataset/val/labels/img_6406.txt
# ...

# %%
yaml_content = """  
path: /kaggle/input/capstone-3-real-datasett  
train: /kaggle/input/capstone-3-real-datasett/Capstone 3 Dataset/train
val: /kaggle/input/capstone-3-real-datasett/Capstone 3 Dataset/val
test: /kaggle/input/capstone-3-real-datasett/Capstone 3 Dataset/test

nc: 8  # Number of classes (update if needed)  
names: ['Algal_Leaf_Rust', 'Bug_Eaten', 'Healthy_Leaf', 'Leaf_BlightBrown_BLight_No',
        'Leaf_Spot', 'Nutrient_Deficiency', 'Red_Spider_Mite', 'Tea_Mosqueto_Bug_Infected']  
"""

# Save YAML file in Kaggle working directory
yaml_path = "/kaggle/working/data.yaml"
with open(yaml_path, "w") as f:
    f.write(yaml_content.strip())

print(f"✅ YAML file created at: {yaml_path}")
# Out:
# ✅ YAML file created at: /kaggle/working/data.yaml

# %%
# !pip install ultralytics  
from ultralytics import YOLO  

# Load YOLOv8 model  
model = YOLO("yolov8n.pt")  # YOLOv8 nano  

# Train on Kaggle Dataset  
model.train(data="/kaggle/working/data.yaml", epochs=100, batch=16, imgsz=640, device="cuda")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 914.7/914.7 kB 18.4 MB/s eta 0:00:00
# ...
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# 100%|██████████| 6.25M/6.25M [00:00<00:00, 85.9MB/s]
# Ultralytics 8.3.74 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15095MiB)
# ...
